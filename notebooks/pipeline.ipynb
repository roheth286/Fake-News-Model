# %% [markdown]
# # **Fake News Detection Pipeline**
#
# This notebook runs the Fake News detection machine learning pipeline step-by-step. Each cell runs a specific stage of the pipeline implemented in modular script files under `src/`.

# %% [markdown]
# ### **Step 1: Import and Load Datasets**
#
# We load the training and testing datasets from the `data/` folder automatically.

# %%
import pandas as pd

# Load train and test datasets automatically
train_df = pd.read_csv('../data/train.csv')
test_df = pd.read_csv('../data/test.csv')

print("Training Dataset Shape:", train_df.shape)
print("Testing Dataset Shape:", test_df.shape)

# %% [markdown]
# ### **Step 2: Preprocessing & Data Cleaning**
#
# Runs the text cleaning stage to combine title, author, and text and apply NLTK stopwords/lemmatizer.

# %%
# %run ../src/data_cleaning.py

# %% [markdown]
# ### **Step 3: Feature Extraction**
#
# Fits a TF-IDF vectorizer (5000 features max) and transforms the cleaned text data into sparse matrices.

# %%
# %run ../src/feature_extraction.py

# %% [markdown]
# ### **Step 4: Model Training**
#
# Splits training dataset (80% train, 20% validation) and trains a Logistic Regression model.

# %%
# %run ../src/model_training.py

# %% [markdown]
# ### **Step 5: Model Evaluation**
#
# Predicts validation data labels and computes evaluation metrics (classification report, ROC curve plots).

# %%
# %run ../src/model_evaluation.py
